# %%
import requests
import numpy as np
import random
import pandas as pd
import os
import re
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_to_analize = pd.read_csv('/Users/pptrv/IronHack/Week_3-Project/Data/energy_price_vs_generation_data.csv', encoding ='latin1')
data_to_analize.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1457 entries, 0 to 1456
# Data columns (total 4 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Dates                                       1457 non-null   object
#  1   renewable energy generation percentage      1457 non-null   float64
#  2   non-renewable energy generation percentage  1457 non-null   float64
#  3   energy price                                1457 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 45.7+ KB

# %%
data_to_analize.sample(10)
# Out:
#            Dates  renewable energy generation percentage  \
# 825   2017-04-07                                0.388937
# 210   2015-07-30                                0.331662
# 916   2017-07-07                                0.295647
# 226   2015-08-15                                0.260661
# 431   2016-03-08                                0.594280
# 273   2015-10-01                                0.269732
# 621   2016-09-14                                0.374888
# 450   2016-03-27                                0.578025
# 1076  2017-12-14                                0.377444
# 478   2016-04-24                                0.522970
#
#       non-renewable energy generation percentage  energy price
# 825                                     0.611063     53.964583
# 210                                     0.668338     70.157500
# 916                                     0.704353     56.109167
# 226                                     0.739339     58.182500
# ...

# %% [markdown]
# ## Basic Statistics & Plots

# %%
data_to_analize.Dates.describe()
# Out:
# count           1457
# unique          1457
# top       2018-04-27
# freq               1
# Name: Dates, dtype: object

# %%
data_to_analize["renewable energy generation percentage"].describe()
# Out:
# count    1457.000000
# mean        0.376835
# std         0.107801
# min         0.140193
# 25%         0.295647
# 50%         0.360257
# 75%         0.455346
# max         0.710847
# Name: renewable energy generation percentage, dtype: float64

# %%
sns.boxplot(y="renewable energy generation percentage", data=data_to_analize)
# Out:
# <AxesSubplot:ylabel='renewable energy generation percentage'>

# %%
data_to_analize["non-renewable energy generation percentage"].describe()
# Out:
# count    1457.000000
# mean        0.623165
# std         0.107801
# min         0.289153
# 25%         0.544654
# 50%         0.639743
# 75%         0.704353
# max         0.859807
# Name: non-renewable energy generation percentage, dtype: float64

# %%
sns.boxplot(y="non-renewable energy generation percentage", data=data_to_analize)
# Out:
# <AxesSubplot:ylabel='non-renewable energy generation percentage'>

# %%
data_to_analize["energy price"].describe()
# Out:
# count    1457.000000
# mean       57.891985
# std        12.052625
# min        14.514583
# 25%        50.827500
# 50%        58.592083
# 75%        66.507500
# max        98.982917
# Name: energy price, dtype: float64

# %%
sns.boxplot(y="energy price", data=data_to_analize)
# Out:
# <AxesSubplot:ylabel='energy price'>

# %%
labels = ['Non-renewable', 'Renewable']
sizes = [0.623165,0.376835]

plt.pie(sizes, labels=labels)
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Proving our Hypothesis

# %% [markdown]
# Hypothesis: *Generating energy with renewable alternatives decreases the energy market price*

# %%
sns.scatterplot(x="energy price", y="non-renewable energy generation percentage", data=data_to_analize)
# Out:
# <AxesSubplot:xlabel='energy price', ylabel='non-renewable energy generation percentage'>

# %% [markdown]
# By using a scatterplt we are able to clearly identify a well defined positive correlation between price and renewable energy.

# %%
sns.scatterplot(x="energy price", y="renewable energy generation percentage", data=data_to_analize)
# Out:
# <AxesSubplot:xlabel='energy price', ylabel='renewable energy generation percentage'>

# %% [markdown]
# By using a scatterplt we are able to clearly identify a well defined negative correlation between price and renewable energy.

# %% [markdown]
# Our hypothesis is proven correct, the more renewable energy we use, the lower the energy price.
